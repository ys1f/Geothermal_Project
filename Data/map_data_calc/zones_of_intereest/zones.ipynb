# %% [markdown]
# ## Python Script for Well Cluster Analysis (Concise Explanation)
#
# This script analyzes well data from an Excel file to identify spatial clusters based on location using DBSCAN. It then filters these clusters by minimum well count and maximum area, providing detailed information about the valid clusters and the wells within them.
#
# **Key Configuration:**
#
# -   **File Paths:** Input Excel (`excel_file_path`), Output CSV (`output_csv_path`).
# -   **Clustering:** Minimum wells per cluster (`MIN_WELLS_IN_CLUSTER`), maximum cluster area in km² (`MAX_CLUSTER_AREA_KM2`), DBSCAN epsilon in km (`EPS_KM`).
# -   **Column Names:** Specify the exact names for Latitude (`LAT_COL`), Longitude (`LON_COL`), Interpolated gradient (`GRADIENT_COL`), and BHT (`BHT_COL`).
#
# **Main Steps:**
#
# 1.  **Load Data:** Reads well data from the specified Excel file.
# 2.  **Clean Data:** Removes rows with missing or invalid data in essential columns.
# 3.  **Cluster Wells:** Uses DBSCAN to group wells based on their geographic proximity.
# 4.  **Analyze Clusters:**
#     -   Filters clusters based on the minimum number of wells.
#     -   Calculates the area of each remaining cluster using UTM projection.
#     -   Keeps only clusters whose area is within the specified maximum.
# 5.  **Calculate Zone Statistics:** For valid clusters (zones), calculates the average latitude, longitude, gradient, and BHT.
# 6.  **Prepare Output:** Creates a CSV file containing detailed information for each well in a valid zone, including a zone ID, zone statistics, and the well's original data.
#
# **Output CSV File:**
#
# The output CSV file will contain:
#
# -   `zone_id`: Unique identifier for each valid cluster.
# -   `zone_num_wells`: Number of wells in the zone.
# -   `zone_center_latitude`, `zone_center_longitude`: Center coordinates of the zone.
# -   `zone_area_km2`: Area of the zone in square kilometers.
# -   `zone_average_gradient`, `zone_average_bht`: Average gradient and BHT within the zone.
# -   All original columns from the input Excel file for each well.

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import DBSCAN
from scipy.spatial import ConvexHull
from pyproj import Proj, Transformer
import math
import warnings

# --- Configuration ---
# !!! 'Latitude', 'Longitude', 'Interpolated gradient', 'BHT', 'Name', 'Api' (or adjust names below)
excel_file_path = 'wells_with_bht.xlsx'
output_csv_path = 'well_clusters_detailed_analysis.csv' # Changed output filename

# Clustering parameters
MIN_WELLS_IN_CLUSTER = 5 # Corresponds to "5 or more wells" (CHANGED FROM 6)
MAX_CLUSTER_AREA_KM2 = 1.0 # Maximum area constraint
# DBSCAN eps: Maximum distance between samples for one to be considered as in the neighborhood of the other.
# We set it based on the area constraint. A 1km radius circle is ~3.14 km^2. A 1km^2 circle has radius ~0.56km.
# Let's use eps related to ~0.7 km as a starting point (might need tuning).
# Earth radius in kilometers
EARTH_RADIUS_KM = 6371.0
EPS_KM = 0.7 # distance in km
# Convert distance to radians for Haversine metric in DBSCAN
eps_rad = EPS_KM / EARTH_RADIUS_KM

# Columns to use (Adjust these names if they are different in your Excel file)
# Make sure these match your Excel file exactly (case-sensitive)
LAT_COL = 'Latitude'
LON_COL = 'Longitude'
GRADIENT_COL = 'Interpolated gradient' # Or the actual name for gradient
BHT_COL = 'BHT' # Or the actual name for Bottom Hole Temperature
# We don't strictly need Name/API for the logic, but they will be in the output
# NAME_COL = 'Name'
# API_COL = 'Api'

# --- Helper Functions ---

def get_utm_zone(longitude):
    """Estimates the UTM zone number from longitude."""
    return int(math.floor((longitude + 180) / 6) + 1)

def calculate_utm_area(lat_lon_points, lat_col_name, lon_col_name):
    """
    Calculates the area of the convex hull of points in km^2 using UTM projection.
    Args:
        lat_lon_points (pd.DataFrame): DataFrame with latitude and longitude columns.
        lat_col_name (str): Name of the latitude column.
        lon_col_name (str): Name of the longitude column.
    Returns:
        float: Area in square kilometers, or None if calculation fails.
    """
    if len(lat_lon_points) < 3:
        # Convex hull requires at least 3 points. Area is 0 for fewer points or co-linear points.
        return 0.0

    # Use the centroid to determine the UTM zone
    center_lat = lat_lon_points[lat_col_name].mean()
    center_lon = lat_lon_points[lon_col_name].mean()
    utm_zone = get_utm_zone(center_lon)

    # Determine if it's North or South hemisphere
    hemisphere = 'north' if center_lat >= 0 else 'south'

    # Define WGS84 and the target UTM projection
    wgs84 = 'epsg:4326' # Standard Lat/Lon
    utm_crs = f'+proj=utm +zone={utm_zone} +{hemisphere} +ellps=WGS84 +datum=WGS84 +units=m +no_defs'

    try:
        # Create a transformer
        transformer = Transformer.from_crs(wgs84, utm_crs, always_xy=True) # lon, lat order

        # Transform points to UTM coordinates (meters)
        utm_coords = [transformer.transform(lon, lat) for lon, lat in zip(lat_lon_points[lon_col_name], lat_lon_points[lat_col_name])]
        utm_points = np.array(utm_coords)

        # Calculate the convex hull
        hull = ConvexHull(utm_points)

        # Area of the convex hull in square meters
        area_m2 = hull.volume # In 2D, 'volume' gives the area

        # Convert area to square kilometers
        area_km2 = area_m2 / 1_000_000
        return area_km2

    except Exception as e:
        warnings.warn(f"Could not calculate UTM area for cluster around ({center_lat:.4f}, {center_lon:.4f}): {e}")
        # Fallback or error handling: Could return None, 0, or estimate differently
        return None


# --- Main Script ---

print(f"Loading data from: {excel_file_path}")
try:
    df = pd.read_excel(excel_file_path)
    print(f"Loaded {len(df)} wells.")
    print("Original columns:", df.columns.tolist()) # Print column names to help debugging
except FileNotFoundError:
    print(f"ERROR: File not found at {excel_file_path}")
    print("Please ensure the file exists and the path is correct.")
    exit()
except Exception as e:
    print(f"ERROR: Could not read Excel file: {e}")
    exit()

# Basic Data Cleaning / Preparation
# Check required columns exist
required_cols_logic = [LAT_COL, LON_COL, GRADIENT_COL, BHT_COL]
missing_cols = [col for col in required_cols_logic if col not in df.columns]
if missing_cols:
    print(f"ERROR: Missing required columns for calculations: {missing_cols}")
    print(f"Please ensure the columns are named correctly (case-sensitive). Expected: {required_cols_logic}")
    exit()

# Keep track of original columns for final output
original_columns = df.columns.tolist()

# Drop rows with missing essential data for clustering/calculations
df_clean = df.dropna(subset=required_cols_logic).copy()
print(f"Processing {len(df_clean)} wells after removing rows with missing essential data ({required_cols_logic}).")

# Convert coordinates and key numeric columns to numeric, coercing errors
for col in required_cols_logic:
     df_clean[col] = pd.to_numeric(df_clean[col], errors='coerce')

# Drop rows where conversion failed for essential columns
initial_count = len(df_clean)
df_clean = df_clean.dropna(subset=required_cols_logic)
if len(df_clean) < initial_count:
     print(f"Removed {initial_count - len(df_clean)} additional rows due to non-numeric values in essential columns.")

if len(df_clean) < MIN_WELLS_IN_CLUSTER:
    print(f"Not enough valid wells ({len(df_clean)}) to form a cluster of size >= {MIN_WELLS_IN_CLUSTER}. Exiting.")
    exit()

# Convert lat/lon to radians for DBSCAN haversine metric
df_clean['lat_rad'] = np.radians(df_clean[LAT_COL])
df_clean['lon_rad'] = np.radians(df_clean[LON_COL])
coords_rad = df_clean[['lat_rad', 'lon_rad']].values

print(f"Running DBSCAN with eps={EPS_KM:.2f} km ({eps_rad:.6f} radians) and min_samples={MIN_WELLS_IN_CLUSTER}...")
# Run DBSCAN
# Use min_samples = MIN_WELLS_IN_CLUSTER (now 5)
db = DBSCAN(eps=eps_rad, min_samples=MIN_WELLS_IN_CLUSTER, metric='haversine', algorithm='ball_tree')
db.fit(coords_rad)

# Add cluster labels to the dataframe
df_clean['cluster_label'] = db.labels_
n_clusters = len(set(db.labels_)) - (1 if -1 in db.labels_ else 0)
n_noise = list(db.labels_).count(-1)
print(f'Estimated number of clusters: {n_clusters}')
print(f'Estimated number of noise points: {n_noise}')

# Process valid clusters and collect data per well
results_per_well = [] # Store results here, one entry per well in a valid zone
valid_cluster_labels = sorted([label for label in set(db.labels_) if label != -1])

print("Analyzing identified clusters...")
zone_counter = 0 # Use a simple counter for zone IDs
for label in valid_cluster_labels:
    cluster_mask = (df_clean['cluster_label'] == label)
    cluster_df = df_clean[cluster_mask].copy() # Use .copy() to avoid SettingWithCopyWarning later
    num_wells = len(cluster_df)

    # Check if the cluster meets the minimum size requirement (CHANGED to >=)
    if num_wells >= MIN_WELLS_IN_CLUSTER:
        print(f"  Cluster Label {label}: Found {num_wells} wells (>= {MIN_WELLS_IN_CLUSTER}). Checking area...")

        # Calculate cluster area using UTM projection
        cluster_coords = cluster_df[[LAT_COL, LON_COL]]
        zone_area_km2 = calculate_utm_area(cluster_coords, LAT_COL, LON_COL)

        if zone_area_km2 is not None and zone_area_km2 <= MAX_CLUSTER_AREA_KM2:
            zone_id = zone_counter # Assign a sequential ID to the valid zone
            print(f"    -> Area: {zone_area_km2:.4f} km^2 (within threshold). Zone ID: {zone_id}. Calculating stats...")

            # Calculate zone-level statistics
            zone_center_latitude = cluster_df[LAT_COL].mean()
            zone_center_longitude = cluster_df[LON_COL].mean()
            zone_average_gradient = cluster_df[GRADIENT_COL].mean()
            zone_average_bht = cluster_df[BHT_COL].mean()

            # Prepare zone info to add to each well's data
            zone_info = {
                'zone_id': zone_id,
                'zone_num_wells': num_wells,
                'zone_center_latitude': zone_center_latitude,
                'zone_center_longitude': zone_center_longitude,
                'zone_area_km2': zone_area_km2,
                'zone_average_gradient': zone_average_gradient,
                'zone_average_bht': zone_average_bht
            }
            print(f"    -> Zone {zone_id} added.")

            # Add zone information to each well in this cluster
            # Iterate through the wells of the valid cluster
            for index, well_row in cluster_df.iterrows():
                # Convert the well's original data row to a dictionary
                well_data = well_row.to_dict()
                # Add the calculated zone information to this well's dictionary
                well_data.update(zone_info)
                # Append the combined dictionary to the results list
                results_per_well.append(well_data)

            zone_counter += 1 # Increment zone ID for the next valid zone

        elif zone_area_km2 is None:
             print(f"    -> Area calculation failed for Cluster Label {label}. Skipping.")
        else:
            print(f"    -> Area: {zone_area_km2:.4f} km^2 (exceeds threshold of {MAX_CLUSTER_AREA_KM2} km^2). Skipping Cluster Label {label}.")
    # else: # Optional: log clusters found but with < MIN_WELLS_IN_CLUSTER wells
       # print(f"  Cluster Label {label} has {num_wells} wells (< {MIN_WELLS_IN_CLUSTER}). Skipping.")


# Create output DataFrame from the list of well dictionaries
if results_per_well:
    output_df = pd.DataFrame(results_per_well)
    print(f"\nProcessed {len(output_df)} wells belonging to {zone_counter} valid zones.")

    # Clean up intermediate columns and reorder for clarity
    cols_to_drop = ['lat_rad', 'lon_rad', 'cluster_label']
    output_df = output_df.drop(columns=[col for col in cols_to_drop if col in output_df.columns])

    # Define desired column order (zone info first, then original columns)
    zone_info_cols = [
        'zone_id', 'zone_num_wells', 'zone_center_latitude', 'zone_center_longitude',
        'zone_area_km2', 'zone_average_gradient', 'zone_average_bht'
    ]
    # Ensure original columns don't overlap with new zone info names by mistake
    final_original_cols = [col for col in original_columns if col in output_df.columns and col not in zone_info_cols]
    final_column_order = zone_info_cols + final_original_cols

    # Reorder columns
    output_df = output_df[final_column_order]


    print(f"Saving detailed results to: {output_csv_path}")
    try:
        # Save to CSV
        output_df.to_csv(output_csv_path, index=False, encoding='utf-8')
        print("Results saved successfully.")
    except Exception as e:
        print(f"ERROR: Could not save results to CSV: {e}")
else:
    print(f"\nNo zones found meeting the specified criteria ({MIN_WELLS_IN_CLUSTER} or more wells AND area <= {MAX_CLUSTER_AREA_KM2} km^2).")
# Out:
# Loading data from: wells_with_bht.xlsx
# Loaded 11201 wells.
# Original columns: ['Name', 'Api', 'Country', 'Status', 'Well Type', 'Latitude', 'Longitude', 'True Vertical Depth (ft)', 'True Vertical Depth (km)', 'Interpolated gradient', 'BHT', 'Suitable for ']
# Processing 11201 wells after removing rows with missing essential data (['Latitude', 'Longitude', 'Interpolated gradient', 'BHT']).
# Running DBSCAN with eps=0.70 km (0.000110 radians) and min_samples=5...
# Estimated number of clusters: 117
# Estimated number of noise points: 9731
# Analyzing identified clusters...
#   Cluster Label 0: Found 11 wells (>= 5). Checking area...
#     -> Area: 1.6721 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 0.
#   Cluster Label 1: Found 5 wells (>= 5). Checking area...
#     -> Area: 0.3129 km^2 (within threshold). Zone ID: 0. Calculating stats...
#     -> Zone 0 added.
#   Cluster Label 2: Found 45 wells (>= 5). Checking area...
#     -> Area: 8.8262 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 2.
#   Cluster Label 3: Found 6 wells (>= 5). Checking area...
#     -> Area: 0.4817 km^2 (within threshold). Zone ID: 1. Calculating stats...
#     -> Zone 1 added.
#   Cluster Label 4: Found 5 wells (>= 5). Checking area...
#     -> Area: 0.3673 km^2 (within threshold). Zone ID: 2. Calculating stats...
#     -> Zone 2 added.
#   Cluster Label 5: Found 5 wells (>= 5). Checking area...
#     -> Area: 0.3741 km^2 (within threshold). Zone ID: 3. Calculating stats...
#     -> Zone 3 added.
#   Cluster Label 6: Found 26 wells (>= 5). Checking area...
#     -> Area: 5.1423 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 6.
#   Cluster Label 7: Found 9 wells (>= 5). Checking area...
#     -> Area: 0.9221 km^2 (within threshold). Zone ID: 4. Calculating stats...
#     -> Zone 4 added.
#   Cluster Label 8: Found 22 wells (>= 5). Checking area...
#     -> Area: 2.6777 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 8.
#   Cluster Label 9: Found 6 wells (>= 5). Checking area...
#     -> Area: 0.5459 km^2 (within threshold). Zone ID: 5. Calculating stats...
#     -> Zone 5 added.
#   Cluster Label 10: Found 18 wells (>= 5). Checking area...
#     -> Area: 3.4532 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 10.
#   Cluster Label 11: Found 7 wells (>= 5). Checking area...
#     -> Area: 0.5736 km^2 (within threshold). Zone ID: 6. Calculating stats...
#     -> Zone 6 added.
#   Cluster Label 12: Found 46 wells (>= 5). Checking area...
#     -> Area: 11.0345 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 12.
#   Cluster Label 13: Found 17 wells (>= 5). Checking area...
#     -> Area: 3.1916 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 13.
#   Cluster Label 14: Found 6 wells (>= 5). Checking area...
#     -> Area: 0.4648 km^2 (within threshold). Zone ID: 7. Calculating stats...
#     -> Zone 7 added.
#   Cluster Label 15: Found 5 wells (>= 5). Checking area...
#     -> Area: 0.4632 km^2 (within threshold). Zone ID: 8. Calculating stats...
#     -> Zone 8 added.
#   Cluster Label 16: Found 20 wells (>= 5). Checking area...
#     -> Area: 2.7567 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 16.
#   Cluster Label 17: Found 5 wells (>= 5). Checking area...
#     -> Area: 0.4540 km^2 (within threshold). Zone ID: 9. Calculating stats...
#     -> Zone 9 added.
#   Cluster Label 18: Found 6 wells (>= 5). Checking area...
#     -> Area: 0.4885 km^2 (within threshold). Zone ID: 10. Calculating stats...
#     -> Zone 10 added.
#   Cluster Label 19: Found 9 wells (>= 5). Checking area...
#     -> Area: 1.2023 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 19.
#   Cluster Label 20: Found 6 wells (>= 5). Checking area...
#     -> Area: 0.6378 km^2 (within threshold). Zone ID: 11. Calculating stats...
#     -> Zone 11 added.
#   Cluster Label 21: Found 6 wells (>= 5). Checking area...
#     -> Area: 0.1767 km^2 (within threshold). Zone ID: 12. Calculating stats...
#     -> Zone 12 added.
#   Cluster Label 22: Found 5 wells (>= 5). Checking area...
#     -> Area: 0.5024 km^2 (within threshold). Zone ID: 13. Calculating stats...
#     -> Zone 13 added.
#   Cluster Label 23: Found 11 wells (>= 5). Checking area...
#     -> Area: 1.5171 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 23.
#   Cluster Label 24: Found 5 wells (>= 5). Checking area...
#     -> Area: 0.3641 km^2 (within threshold). Zone ID: 14. Calculating stats...
#     -> Zone 14 added.
#   Cluster Label 25: Found 8 wells (>= 5). Checking area...
#     -> Area: 0.8005 km^2 (within threshold). Zone ID: 15. Calculating stats...
#     -> Zone 15 added.
#   Cluster Label 26: Found 8 wells (>= 5). Checking area...
#     -> Area: 0.5444 km^2 (within threshold). Zone ID: 16. Calculating stats...
#     -> Zone 16 added.
#   Cluster Label 27: Found 23 wells (>= 5). Checking area...
#     -> Area: 3.7413 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 27.
#   Cluster Label 28: Found 22 wells (>= 5). Checking area...
#     -> Area: 2.8707 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 28.
#   Cluster Label 29: Found 10 wells (>= 5). Checking area...
#     -> Area: 1.3738 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 29.
#   Cluster Label 30: Found 5 wells (>= 5). Checking area...
#     -> Area: 0.1548 km^2 (within threshold). Zone ID: 17. Calculating stats...
#     -> Zone 17 added.
#   Cluster Label 31: Found 9 wells (>= 5). Checking area...
#     -> Area: 0.4132 km^2 (within threshold). Zone ID: 18. Calculating stats...
#     -> Zone 18 added.
#   Cluster Label 32: Found 29 wells (>= 5). Checking area...
#     -> Area: 5.5415 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 32.
#   Cluster Label 33: Found 7 wells (>= 5). Checking area...
#     -> Area: 0.4763 km^2 (within threshold). Zone ID: 19. Calculating stats...
#     -> Zone 19 added.
#   Cluster Label 34: Found 35 wells (>= 5). Checking area...
#     -> Area: 4.2264 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 34.
#   Cluster Label 35: Found 8 wells (>= 5). Checking area...
#     -> Area: 0.5268 km^2 (within threshold). Zone ID: 20. Calculating stats...
#     -> Zone 20 added.
#   Cluster Label 36: Found 63 wells (>= 5). Checking area...
#     -> Area: 9.8931 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 36.
#   Cluster Label 37: Found 81 wells (>= 5). Checking area...
#     -> Area: 19.5472 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 37.
#   Cluster Label 38: Found 17 wells (>= 5). Checking area...
#     -> Area: 1.9142 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 38.
#   Cluster Label 39: Found 12 wells (>= 5). Checking area...
#     -> Area: 1.8651 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 39.
#   Cluster Label 40: Found 40 wells (>= 5). Checking area...
#     -> Area: 5.6009 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 40.
#   Cluster Label 41: Found 6 wells (>= 5). Checking area...
#     -> Area: 0.2265 km^2 (within threshold). Zone ID: 21. Calculating stats...
#     -> Zone 21 added.
#   Cluster Label 42: Found 11 wells (>= 5). Checking area...
#     -> Area: 1.3575 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 42.
#   Cluster Label 43: Found 64 wells (>= 5). Checking area...
#     -> Area: 12.1163 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 43.
#   Cluster Label 44: Found 7 wells (>= 5). Checking area...
#     -> Area: 0.7044 km^2 (within threshold). Zone ID: 22. Calculating stats...
#     -> Zone 22 added.
#   Cluster Label 45: Found 119 wells (>= 5). Checking area...
#     -> Area: 30.1196 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 45.
#   Cluster Label 46: Found 14 wells (>= 5). Checking area...
#     -> Area: 1.5867 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 46.
#   Cluster Label 47: Found 11 wells (>= 5). Checking area...
#     -> Area: 1.1272 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 47.
#   Cluster Label 48: Found 8 wells (>= 5). Checking area...
#     -> Area: 0.6246 km^2 (within threshold). Zone ID: 23. Calculating stats...
#     -> Zone 23 added.
#   Cluster Label 49: Found 6 wells (>= 5). Checking area...
#     -> Area: 0.2962 km^2 (within threshold). Zone ID: 24. Calculating stats...
#     -> Zone 24 added.
#   Cluster Label 50: Found 5 wells (>= 5). Checking area...
#     -> Area: 0.3693 km^2 (within threshold). Zone ID: 25. Calculating stats...
#     -> Zone 25 added.
#   Cluster Label 51: Found 5 wells (>= 5). Checking area...
#     -> Area: 0.2588 km^2 (within threshold). Zone ID: 26. Calculating stats...
#     -> Zone 26 added.
#   Cluster Label 52: Found 8 wells (>= 5). Checking area...
#     -> Area: 0.7964 km^2 (within threshold). Zone ID: 27. Calculating stats...
#     -> Zone 27 added.
#   Cluster Label 53: Found 7 wells (>= 5). Checking area...
#     -> Area: 0.8210 km^2 (within threshold). Zone ID: 28. Calculating stats...
#     -> Zone 28 added.
#   Cluster Label 54: Found 5 wells (>= 5). Checking area...
#     -> Area: 0.6679 km^2 (within threshold). Zone ID: 29. Calculating stats...
#     -> Zone 29 added.
#   Cluster Label 55: Found 5 wells (>= 5). Checking area...
#     -> Area: 0.4570 km^2 (within threshold). Zone ID: 30. Calculating stats...
#     -> Zone 30 added.
#   Cluster Label 56: Found 7 wells (>= 5). Checking area...
#     -> Area: 0.8684 km^2 (within threshold). Zone ID: 31. Calculating stats...
#     -> Zone 31 added.
#   Cluster Label 57: Found 5 wells (>= 5). Checking area...
#     -> Area: 0.4865 km^2 (within threshold). Zone ID: 32. Calculating stats...
#     -> Zone 32 added.
#   Cluster Label 58: Found 5 wells (>= 5). Checking area...
#     -> Area: 0.3308 km^2 (within threshold). Zone ID: 33. Calculating stats...
#     -> Zone 33 added.
#   Cluster Label 59: Found 31 wells (>= 5). Checking area...
#     -> Area: 5.8861 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 59.
#   Cluster Label 60: Found 10 wells (>= 5). Checking area...
#     -> Area: 1.6235 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 60.
#   Cluster Label 61: Found 9 wells (>= 5). Checking area...
#     -> Area: 1.6327 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 61.
#   Cluster Label 62: Found 10 wells (>= 5). Checking area...
#     -> Area: 2.1130 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 62.
#   Cluster Label 63: Found 5 wells (>= 5). Checking area...
#     -> Area: 0.2427 km^2 (within threshold). Zone ID: 34. Calculating stats...
#     -> Zone 34 added.
#   Cluster Label 64: Found 6 wells (>= 5). Checking area...
#     -> Area: 0.3124 km^2 (within threshold). Zone ID: 35. Calculating stats...
#     -> Zone 35 added.
#   Cluster Label 65: Found 13 wells (>= 5). Checking area...
#     -> Area: 2.2655 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 65.
#   Cluster Label 66: Found 8 wells (>= 5). Checking area...
#     -> Area: 1.2549 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 66.
#   Cluster Label 67: Found 6 wells (>= 5). Checking area...
#     -> Area: 0.0218 km^2 (within threshold). Zone ID: 36. Calculating stats...
#     -> Zone 36 added.
#   Cluster Label 68: Found 6 wells (>= 5). Checking area...
#     -> Area: 0.2834 km^2 (within threshold). Zone ID: 37. Calculating stats...
#     -> Zone 37 added.
#   Cluster Label 69: Found 6 wells (>= 5). Checking area...
#     -> Area: 0.1118 km^2 (within threshold). Zone ID: 38. Calculating stats...
#     -> Zone 38 added.
#   Cluster Label 70: Found 5 wells (>= 5). Checking area...
#     -> Area: 0.3152 km^2 (within threshold). Zone ID: 39. Calculating stats...
#     -> Zone 39 added.
#   Cluster Label 71: Found 6 wells (>= 5). Checking area...
#     -> Area: 0.0033 km^2 (within threshold). Zone ID: 40. Calculating stats...
#     -> Zone 40 added.
#   Cluster Label 72: Found 6 wells (>= 5). Checking area...
#     -> Area: 0.0054 km^2 (within threshold). Zone ID: 41. Calculating stats...
#     -> Zone 41 added.
#   Cluster Label 73: Found 6 wells (>= 5). Checking area...
#     -> Area: 0.0034 km^2 (within threshold). Zone ID: 42. Calculating stats...
#     -> Zone 42 added.
#   Cluster Label 74: Found 5 wells (>= 5). Checking area...
#     -> Area: 0.0000 km^2 (within threshold). Zone ID: 43. Calculating stats...
#     -> Zone 43 added.
#   Cluster Label 75: Found 6 wells (>= 5). Checking area...
#     -> Area: 0.0463 km^2 (within threshold). Zone ID: 44. Calculating stats...
#     -> Zone 44 added.
#   Cluster Label 76: Found 7 wells (>= 5). Checking area...
#     -> Area: 0.1601 km^2 (within threshold). Zone ID: 45. Calculating stats...
#     -> Zone 45 added.
#   Cluster Label 77: Found 5 wells (>= 5). Checking area...
#     -> Area: 0.0988 km^2 (within threshold). Zone ID: 46. Calculating stats...
#     -> Zone 46 added.
#   Cluster Label 78: Found 6 wells (>= 5). Checking area...
#     -> Area: 0.1349 km^2 (within threshold). Zone ID: 47. Calculating stats...
#     -> Zone 47 added.
#   Cluster Label 79: Found 16 wells (>= 5). Checking area...
#     -> Area: 1.0314 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 79.
#   Cluster Label 80: Found 5 wells (>= 5). Checking area...
#     -> Area: 0.4644 km^2 (within threshold). Zone ID: 48. Calculating stats...
#     -> Zone 48 added.
#   Cluster Label 81: Found 5 wells (>= 5). Checking area...
#     -> Area: 0.0427 km^2 (within threshold). Zone ID: 49. Calculating stats...
#     -> Zone 49 added.
#   Cluster Label 82: Found 6 wells (>= 5). Checking area...
#     -> Area: 0.0085 km^2 (within threshold). Zone ID: 50. Calculating stats...
#     -> Zone 50 added.
#   Cluster Label 83: Found 16 wells (>= 5). Checking area...
#     -> Area: 2.7715 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 83.
#   Cluster Label 84: Found 5 wells (>= 5). Checking area...
#     -> Area: 0.0016 km^2 (within threshold). Zone ID: 51. Calculating stats...
#     -> Zone 51 added.
#   Cluster Label 85: Found 13 wells (>= 5). Checking area...
#     -> Area: 1.7568 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 85.
#   Cluster Label 86: Found 6 wells (>= 5). Checking area...
#     -> Area: 0.3953 km^2 (within threshold). Zone ID: 52. Calculating stats...
#     -> Zone 52 added.
#   Cluster Label 87: Found 5 wells (>= 5). Checking area...
#     -> Area: 0.0104 km^2 (within threshold). Zone ID: 53. Calculating stats...
#     -> Zone 53 added.
#   Cluster Label 88: Found 6 wells (>= 5). Checking area...
#     -> Area: 0.1032 km^2 (within threshold). Zone ID: 54. Calculating stats...
#     -> Zone 54 added.
#   Cluster Label 89: Found 13 wells (>= 5). Checking area...
#     -> Area: 1.7453 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 89.
#   Cluster Label 90: Found 5 wells (>= 5). Checking area...
#     -> Area: 0.5315 km^2 (within threshold). Zone ID: 55. Calculating stats...
#     -> Zone 55 added.
#   Cluster Label 91: Found 5 wells (>= 5). Checking area...
#     -> Area: 0.1157 km^2 (within threshold). Zone ID: 56. Calculating stats...
#     -> Zone 56 added.
#   Cluster Label 92: Found 27 wells (>= 5). Checking area...
#     -> Area: 4.4142 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 92.
#   Cluster Label 93: Found 9 wells (>= 5). Checking area...
#     -> Area: 0.2176 km^2 (within threshold). Zone ID: 57. Calculating stats...
#     -> Zone 57 added.
#   Cluster Label 94: Found 8 wells (>= 5). Checking area...
#     -> Area: 0.0092 km^2 (within threshold). Zone ID: 58. Calculating stats...
#     -> Zone 58 added.
#   Cluster Label 95: Found 5 wells (>= 5). Checking area...
#     -> Area: 0.0344 km^2 (within threshold). Zone ID: 59. Calculating stats...
#     -> Zone 59 added.
#   Cluster Label 96: Found 6 wells (>= 5). Checking area...
#     -> Area: 0.0123 km^2 (within threshold). Zone ID: 60. Calculating stats...
#     -> Zone 60 added.
#   Cluster Label 97: Found 10 wells (>= 5). Checking area...
#     -> Area: 0.0124 km^2 (within threshold). Zone ID: 61. Calculating stats...
#     -> Zone 61 added.
#   Cluster Label 98: Found 5 wells (>= 5). Checking area...
#     -> Area: 0.3372 km^2 (within threshold). Zone ID: 62. Calculating stats...
#     -> Zone 62 added.
#   Cluster Label 99: Found 7 wells (>= 5). Checking area...
#     -> Area: 0.7515 km^2 (within threshold). Zone ID: 63. Calculating stats...
#     -> Zone 63 added.
#   Cluster Label 100: Found 6 wells (>= 5). Checking area...
#     -> Area: 0.4464 km^2 (within threshold). Zone ID: 64. Calculating stats...
#     -> Zone 64 added.
#   Cluster Label 101: Found 5 wells (>= 5). Checking area...
#     -> Area: 0.3229 km^2 (within threshold). Zone ID: 65. Calculating stats...
#     -> Zone 65 added.
#   Cluster Label 102: Found 6 wells (>= 5). Checking area...
#     -> Area: 0.3772 km^2 (within threshold). Zone ID: 66. Calculating stats...
#     -> Zone 66 added.
#   Cluster Label 103: Found 5 wells (>= 5). Checking area...
#     -> Area: 0.4953 km^2 (within threshold). Zone ID: 67. Calculating stats...
#     -> Zone 67 added.
#   Cluster Label 104: Found 7 wells (>= 5). Checking area...
#     -> Area: 0.1843 km^2 (within threshold). Zone ID: 68. Calculating stats...
#     -> Zone 68 added.
#   Cluster Label 105: Found 8 wells (>= 5). Checking area...
#     -> Area: 0.0411 km^2 (within threshold). Zone ID: 69. Calculating stats...
#     -> Zone 69 added.
#   Cluster Label 106: Found 5 wells (>= 5). Checking area...
#     -> Area: 0.1509 km^2 (within threshold). Zone ID: 70. Calculating stats...
#     -> Zone 70 added.
#   Cluster Label 107: Found 5 wells (>= 5). Checking area...
#     -> Area: 0.0489 km^2 (within threshold). Zone ID: 71. Calculating stats...
#     -> Zone 71 added.
#   Cluster Label 108: Found 11 wells (>= 5). Checking area...
#     -> Area: 1.0548 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 108.
#   Cluster Label 109: Found 6 wells (>= 5). Checking area...
#     -> Area: 0.0045 km^2 (within threshold). Zone ID: 72. Calculating stats...
#     -> Zone 72 added.
#   Cluster Label 110: Found 6 wells (>= 5). Checking area...
#     -> Area: 0.3741 km^2 (within threshold). Zone ID: 73. Calculating stats...
#     -> Zone 73 added.
#   Cluster Label 111: Found 5 wells (>= 5). Checking area...
#     -> Area: 0.0354 km^2 (within threshold). Zone ID: 74. Calculating stats...
#     -> Zone 74 added.
#   Cluster Label 112: Found 6 wells (>= 5). Checking area...
#     -> Area: 0.0567 km^2 (within threshold). Zone ID: 75. Calculating stats...
#     -> Zone 75 added.
#   Cluster Label 113: Found 5 wells (>= 5). Checking area...
#     -> Area: 0.2127 km^2 (within threshold). Zone ID: 76. Calculating stats...
#     -> Zone 76 added.
#   Cluster Label 114: Found 29 wells (>= 5). Checking area...
#     -> Area: 5.4474 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 114.
#   Cluster Label 115: Found 12 wells (>= 5). Checking area...
#     -> Area: 1.2964 km^2 (exceeds threshold of 1.0 km^2). Skipping Cluster Label 115.
#   Cluster Label 116: Found 11 wells (>= 5). Checking area...
#     -> Area: 0.0018 km^2 (within threshold). Zone ID: 77. Calculating stats...
#     -> Zone 77 added.
#
# Processed 476 wells belonging to 78 valid zones.
# Saving detailed results to: well_clusters_detailed_analysis.csv
# Results saved successfully.

# %%
output_df
# Out:
#      zone_id  zone_num_wells  zone_center_latitude  zone_center_longitude  \
# 0          0               5             31.567891            -103.287617
# 1          0               5             31.567891            -103.287617
# 2          0               5             31.567891            -103.287617
# 3          0               5             31.567891            -103.287617
# 4          0               5             31.567891            -103.287617
# ..       ...             ...                   ...                    ...
# 471       77              11             29.263829             -95.015287
# 472       77              11             29.263829             -95.015287
# 473       77              11             29.263829             -95.015287
# 474       77              11             29.263829             -95.015287
# 475       77              11             29.263829             -95.015287
#
#      zone_area_km2  zone_average_gradient  zone_average_bht  \
# 0          0.31295              24.303991         85.868642
# 1          0.31295              24.303991         85.868642
# 2          0.31295              24.303991         85.868642
# 3          0.31295              24.303991         85.868642
# 4          0.31295              24.303991         85.868642
# ..             ...                    ...               ...
# 471        0.00180              12.129166         69.632523
# 472        0.00180              12.129166         69.632523
# 473        0.00180              12.129166         69.632523
# 474        0.00180              12.129166         69.632523
# 475        0.00180              12.129166         69.632523
#
#                                Name         Api    Country  \
# 0              UNIVERSITY "18-31" 3  4247532401       WARD
# 1                UNIVERSITY 18-29 4  4247532501       WARD
# 2                    UNIV "18-31" 2  4247531939       WARD
# 3                UNIVERSITY 18-31 4  4247532553       WARD
# 4                UNIVERSITY 18-31 6  4247532765       WARD
# ..                              ...         ...        ...
# 471         HALLS BAYOU RANCH "3" 3  4216731259  GALVESTON
# 472                STATE OF TEXAS 1  4216731260  GALVESTON
# 473                STATE OF TEXAS 3  4216731396  GALVESTON
# 474            HALLS BAYOU RANCH 8R  4216731349  GALVESTON
# 475  HALLS BAYOU RANCH TR. 4 UNIT 2  4216731409  GALVESTON
#
#                   Status   Well Type   Latitude   Longitude  \
# 0    Plugged & Abandoned     WET GAS  31.564718 -103.290527
# 1    Plugged & Abandoned  CONDENSATE  31.566277 -103.282852
# 2    Plugged & Abandoned    GAS WELL  31.566418 -103.287827
# 3    Plugged & Abandoned     WET GAS  31.569286 -103.287788
# 4    Plugged & Abandoned     WET GAS  31.572758 -103.289093
# ..                   ...         ...        ...         ...
# 471  Plugged & Abandoned     WET GAS  29.263866  -95.015274
# 472  Plugged & Abandoned     WET GAS  29.263834  -95.015274
# 473  Plugged & Abandoned     WET GAS  29.263781  -95.015175
# 474  Plugged & Abandoned     WET GAS  29.263834  -95.015167
# 475  Plugged & Abandoned     Unknown  29.263578  -95.014908
#
#      True Vertical Depth (ft)  True Vertical Depth (km)  \
# 0                 6865.000000                     2.092
# 1                 6825.000000                     2.080
# 2                17067.000000                     5.202
# 3                 6850.000000                     2.088
# 4                 6850.000000                     2.088
# ..                        ...                       ...
# 471              12770.990234                     3.893
# 472              12600.589844                     3.841
# 473              12645.610352                     3.854
# 474              12546.509766                     3.824
# 475              15149.480469                     4.618
#
#      Interpolated gradient         BHT                 Suitable for
# 0                24.320783   70.879079  Suitable for heat generation
# 1                24.312277   70.569536  Suitable for heat generation
# 2                24.311742  146.469682        Electricity generation
# 3                24.296668   70.731443  Suitable for heat generation
# 4                24.278483   70.693472  Suitable for heat generation
# ..                     ...         ...                           ...
# 471              12.127630   67.212864  Suitable for heat generation
# 472              12.127630   66.582228  Suitable for heat generation
# 473              12.115432   66.692874  Suitable for heat generation
# 474              12.114494   66.325823  Suitable for heat generation
# 475              12.082590   75.797402  Suitable for heat generation
#
# [476 rows x 19 columns]

# %%
import pandas as pd
import numpy as np

# --- Configuration ---
# Имя входного файла (результат предыдущего скрипта)
input_csv_path = 'well_clusters_detailed_analysis.csv'
# Имя выходного файла с категориями зон
output_categories_csv_path = 'zone_categories.csv'
# Имя столбца для категоризации (убедитесь, что оно точно совпадает с вашим файлом)
suitability_col = 'Suitable for '
# Имена категорий (должны точно совпадать со значениями в столбце)
cat_electricity = 'Electricity generation'
cat_heat = 'Suitable for heat generation'
cat_mixed = 'mixed'

# --- Main Script ---

print(f"Загрузка данных из: {input_csv_path}")
try:
    df = pd.read_csv(input_csv_path)
    print(f"Загружено {len(df)} записей скважин.")
except FileNotFoundError:
    print(f"ОШИБКА: Файл не найден по пути {input_csv_path}")
    print("Убедитесь, что файл существует и путь указан верно (он должен быть результатом работы предыдущего скрипта).")
    # В Jupyter можно остановить выполнение или обработать иначе
    # raise # Раскомментируйте, если хотите остановить выполнение ячейки при ошибке
    exit() # Используем exit() если запускается как скрипт
except Exception as e:
    print(f"ОШИБКА: Не удалось прочитать CSV файл: {e}")
    # raise
    exit()

# Проверка наличия необходимых столбцов
if 'zone_id' not in df.columns:
    print("ОШИБКА: Отсутствует столбец 'zone_id' во входном файле.")
    exit()
if suitability_col not in df.columns:
    print(f"ОШИБКА: Отсутствует столбец '{suitability_col}' во входном файле.")
    exit()

print(f"Категоризация зон на основе столбца '{suitability_col}'...")

# Группировка по ID зоны
grouped_zones = df.groupby('zone_id')

zone_categories = []

# Итерация по каждой зоне
for zone_id, zone_df in grouped_zones:
    # Получаем уникальные значения 'Suitable for' в этой зоне, игнорируя NaN
    unique_values = zone_df[suitability_col].dropna().unique()

    category = cat_mixed # По умолчанию 'mixed'

    if len(unique_values) == 1:
        # Если только одно уникальное значение (не NaN)
        if unique_values[0] == cat_electricity:
            category = cat_electricity
        elif unique_values[0] == cat_heat:
            category = cat_heat
        # Если одно уникальное значение, но не совпадает с заданными,
        # оно останется 'mixed' (как и было по умолчанию)
    elif len(unique_values) == 0:
         # Если все значения NaN в этой зоне, считаем 'mixed'
         category = cat_mixed
    # Если уникальных значений > 1, категория остается 'mixed'

    zone_categories.append({'zone_id': zone_id, 'category': category})
    print(f"  Зона {zone_id}: Уникальные значения '{suitability_col}': {unique_values} -> Категория: {category}")

# Создание DataFrame с результатами
if zone_categories:
    categories_df = pd.DataFrame(zone_categories)
    print("\n--- Категоризация зон завершена ---")
    # Вывод результата в Jupyter
    from IPython.display import display
    display(categories_df)

    # Сохранение результата в CSV
    try:
        categories_df.to_csv(output_categories_csv_path, index=False, encoding='utf-8')
        print(f"\nКатегории зон сохранены в файл: {output_categories_csv_path}")
    except Exception as e:
        print(f"\nОШИБКА: Не удалось сохранить категории в CSV: {e}")

else:
    print("\nНе найдено зон для категоризации во входном файле.")
# Out:
# Загрузка данных из: well_clusters_detailed_analysis.csv
# Загружено 476 записей скважин.
# Категоризация зон на основе столбца 'Suitable for '...
#   Зона 0: Уникальные значения 'Suitable for ': ['Suitable for heat generation' 'Electricity generation'] -> Категория: mixed
#   Зона 1: Уникальные значения 'Suitable for ': ['Suitable for heat generation' 'Electricity generation'] -> Категория: mixed
#   Зона 2: Уникальные значения 'Suitable for ': ['Suitable for heat generation' 'Electricity generation'] -> Категория: mixed
#   Зона 3: Уникальные значения 'Suitable for ': ['Suitable for heat generation' 'Electricity generation'] -> Категория: mixed
#   Зона 4: Уникальные значения 'Suitable for ': ['Suitable for heat generation' 'Electricity generation'] -> Категория: mixed
#   Зона 5: Уникальные значения 'Suitable for ': ['Suitable for heat generation' 'Electricity generation'] -> Категория: mixed
#   Зона 6: Уникальные значения 'Suitable for ': ['Electricity generation'] -> Категория: Electricity generation
#   Зона 7: Уникальные значения 'Suitable for ': ['Electricity generation'] -> Категория: Electricity generation
#   Зона 8: Уникальные значения 'Suitable for ': ['Electricity generation' 'Suitable for heat generation'] -> Категория: mixed
#   Зона 9: Уникальные значения 'Suitable for ': ['Electricity generation'] -> Категория: Electricity generation
#   Зона 10: Уникальные значения 'Suitable for ': ['Suitable for heat generation' 'Electricity generation'] -> Категория: mixed
#   Зона 11: Уникальные значения 'Suitable for ': ['Electricity generation'] -> Категория: Electricity generation
#   Зона 12: Уникальные значения 'Suitable for ': ['Electricity generation'] -> Категория: Electricity generation
#   Зона 13: Уникальные значения 'Suitable for ': ['Electricity generation'] -> Категория: Electricity generation
#   Зона 14: Уникальные значения 'Suitable for ': ['Electricity generation' 'Suitable for heat generation'] -> Категория: mixed
#   Зона 15: Уникальные значения 'Suitable for ': ['Suitable for heat generation' 'Electricity generation'] -> Категория: mixed
#   Зона 16: Уникальные значения 'Suitable for ': ['Suitable for heat generation' 'Electricity generation'] -> Категория: mixed
#   Зона 17: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 18: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 19: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 20: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 21: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 22: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 23: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 24: Уникальные значения 'Suitable for ': ['Electricity generation'] -> Категория: Electricity generation
#   Зона 25: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 26: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 27: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 28: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 29: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 30: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 31: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 32: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 33: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 34: Уникальные значения 'Suitable for ': ['Suitable for heat generation' 'Electricity generation'] -> Категория: mixed
#   Зона 35: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 36: Уникальные значения 'Suitable for ': ['Suitable for heat generation' 'Electricity generation'] -> Категория: mixed
#   Зона 37: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 38: Уникальные значения 'Suitable for ': ['Electricity generation'] -> Категория: Electricity generation
#   Зона 39: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 40: Уникальные значения 'Suitable for ': ['Electricity generation'] -> Категория: Electricity generation
#   Зона 41: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 42: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 43: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 44: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 45: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 46: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 47: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 48: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 49: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 50: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 51: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 52: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 53: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 54: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 55: Уникальные значения 'Suitable for ': ['Electricity generation'] -> Категория: Electricity generation
#   Зона 56: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 57: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 58: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 59: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 60: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 61: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 62: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 63: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 64: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 65: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 66: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 67: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 68: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 69: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 70: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 71: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 72: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 73: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 74: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 75: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 76: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#   Зона 77: Уникальные значения 'Suitable for ': ['Suitable for heat generation'] -> Категория: Suitable for heat generation
#
# --- Категоризация зон завершена ---
#     zone_id                      category
# 0         0                         mixed
# 1         1                         mixed
# 2         2                         mixed
# 3         3                         mixed
# 4         4                         mixed
# ..      ...                           ...
# 73       73  Suitable for heat generation
# 74       74  Suitable for heat generation
# 75       75  Suitable for heat generation
# 76       76  Suitable for heat generation
# 77       77  Suitable for heat generation
#
# [78 rows x 2 columns]
# Категории зон сохранены в файл: zone_categories.csv
